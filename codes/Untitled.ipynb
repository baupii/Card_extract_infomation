# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
img1 = cv2.imread(r"C:\Users\ADMIN\Desktop\Thay_Lam\CCCD\imgs\c9eca284-d2f4-4958-9304-4d288f4cb4d7_301102231220211.jpeg\c9eca284-d2f4-4958-9304-4d288f4cb4d7_301102231220211.jpeg")
plt.imshow(img1)

# %%
img1
# Out:
# array([[[166, 169, 174],
#         [168, 171, 176],
#         [166, 166, 172],
#         ...,
#         [140, 139, 149],
#         [140, 139, 149],
#         [137, 135, 147]],
#
#        [[162, 165, 170],
#         [158, 161, 166],
#         [154, 154, 160],
#         ...,
#         [130, 129, 138],
#         [134, 133, 142],
#         [132, 131, 141]],
#
#        [[162, 164, 172],
#         [164, 166, 174],
#         [163, 166, 171],
#         ...,
#         [136, 136, 142],
#         [142, 142, 148],
#         [147, 146, 155]],
#
#        ...,
#
#        [[114, 115, 129],
#         [102, 103, 117],
#         [112, 112, 128],
#         ...,
#         [107, 110, 125],
#         [132, 135, 150],
#         [117, 119, 137]],
#
#        [[ 82,  82,  96],
#         [ 96,  96, 110],
#         [ 99, 100, 114],
#         ...,
#         [121, 127, 140],
#         [130, 136, 149],
#         [130, 133, 148]],
#
#        [[103, 103, 117],
#         [108, 108, 122],
#         [114, 115, 129],
# ...

# %%
img2 = cv2.imread(r"C:\Users\ADMIN\Desktop\Thay_Lam\CCCD\imgs\sau6.jpg")
plt.imshow(img2)

# %%
img2
# Out:
# array([[[169, 172, 176],
#         [170, 173, 177],
#         [161, 164, 169],
#         ...,
#         [144, 142, 148],
#         [136, 134, 140],
#         [140, 137, 146]],
#
#        [[160, 163, 167],
#         [163, 166, 170],
#         [142, 145, 150],
#         ...,
#         [132, 130, 136],
#         [147, 145, 151],
#         [141, 138, 147]],
#
#        [[166, 169, 174],
#         [161, 164, 169],
#         [160, 163, 168],
#         ...,
#         [136, 133, 142],
#         [134, 131, 140],
#         [131, 128, 137]],
#
#        ...,
#
#        [[115, 115, 131],
#         [116, 116, 132],
#         [101, 101, 117],
#         ...,
#         [116, 119, 133],
#         [120, 123, 137],
#         [119, 122, 137]],
#
#        [[ 83,  83, 101],
#         [ 92,  92, 110],
#         [100, 100, 116],
#         ...,
#         [128, 133, 148],
#         [138, 143, 158],
#         [141, 145, 163]],
#
#        [[102, 102, 120],
#         [100, 100, 118],
#         [105, 105, 121],
# ...

# %%
# import cv2
# import pyheif
# import numpy as np

# def read_heic(filename):
#     with open(filename, 'rb') as f:
#         heif_file = pyheif.read(f)
#         image = heif_file.get_pil_image()

#     # Convert the PIL image to a numpy array
#     image_np = np.array(image)

#     return image_np

# def convert_pil_to_cv(image_pil):
#     # Convert PIL image to OpenCV BGR format
#     image_cv = cv2.cvtColor(np.array(image_pil), cv2.COLOR_RGB2BGR)
#     return image_cv

# # Replace 'your_file.heic' with the path to your .HEIC file
# heic_file = "C:\Users\ADMIN\Desktop\Thay_Lam\CCCD\imgs\IMG_1709.heic\IMG_1709.heic"

# # Read the .HEIC file and convert it to OpenCV format
# heic_image = read_heic(heic_file)
# bgr_image = convert_pil_to_cv(heic_image)

# # Display the converted image using OpenCV
# plt.imshow(bgr_image)
